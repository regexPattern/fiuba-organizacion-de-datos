# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()
sns.set_palette("colorblind")

# %%
df = pd.read_csv("propiedades.csv")

# %%
df_dummies = pd.get_dummies(df, columns=["property_type", "neighbourhood"], drop_first=True)

# %%
df_dummies.columns
# Out:
# Index(['Unnamed: 0', 'id', 'start_date', 'end_date', 'latitud', 'longitud',
#        'property_rooms', 'property_bedrooms', 'property_surface_total',
#        'property_surface_covered', 'property_price', 'property_title',
#        'precio_m2', 'tipo_precio', 'property_type_Departamento',
#        'property_type_PH', 'neighbourhood_Agronomía', 'neighbourhood_Almagro',
#        'neighbourhood_Balvanera', 'neighbourhood_Barracas',
#        'neighbourhood_Barrio Norte', 'neighbourhood_Belgrano',
#        'neighbourhood_Boca', 'neighbourhood_Boedo', 'neighbourhood_Caballito',
#        'neighbourhood_Catalinas', 'neighbourhood_Centro / Microcentro',
#        'neighbourhood_Chacarita', 'neighbourhood_Coghlan',
#        'neighbourhood_Colegiales', 'neighbourhood_Congreso',
#        'neighbourhood_Constitución', 'neighbourhood_Flores',
#        'neighbourhood_Floresta', 'neighbourhood_Las Cañitas',
#        'neighbourhood_Liniers', 'neighbourhood_Mataderos',
#        'neighbourhood_Monserrat', 'neighbourhood_Monte Castro',
#        'neighbourhood_Nuñez', 'neighbourhood_Once', 'neighbourhood_Palermo',
#        'neighbourhood_Parque Avellaneda', 'neighbourhood_Parque Centenario',
#        'neighbourhood_Parque Chacabuco', 'neighbourhood_Parque Chas',
#        'neighbourhood_Parque Patricios', 'neighbourhood_Paternal',
#        'neighbourhood_Pompeya', 'neighbourhood_Puerto Madero',
#        'neighbourhood_Recoleta', 'neighbourhood_Retiro',
#        'neighbourhood_Saavedra', 'neighbourhood_San Cristobal',
#        'neighbourhood_San Nicolás', 'neighbourhood_San Telmo',
#        'neighbourhood_Tribunales', 'neighbourhood_Velez Sarsfield',
#        'neighbourhood_Versalles', 'neighbourhood_Villa Crespo',
#        'neighbourhood_Villa Devoto', 'neighbourhood_Villa General Mitre',
#        'neighbourhood_Villa Lugano', 'neighbourhood_Villa Luro',
#        'neighbourhood_Villa Ortuzar', 'neighbourhood_Villa Pueyrredón',
#        'neighbourhood_Villa Real', 'neighbourhood_Villa Riachuelo',
#        'neighbourhood_Villa Santa Rita', 'neighbourhood_Villa Soldati',
#        'neighbourhood_Villa Urquiza', 'neighbourhood_Villa del Parque'],
#       dtype='object')

# %%
df = df_dummies

# %%
from sklearn.model_selection import train_test_split

onehot_cols = [col for col in df.columns if col.startswith(("property_type_","neighbourhood_"))]
num_cols = ["property_rooms", "property_bedrooms", "property_surface_total", "property_surface_covered"]

X = df[onehot_cols + num_cols]
y = df["tipo_precio"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=137)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

ct = ColumnTransformer([
    ("scaling", StandardScaler(), num_cols)
], remainder="passthrough")

X_train_trans = ct.fit_transform(X_train)

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV, StratifiedShuffleSplit
from sklearn.svm import SVC

Cs = [1, 10, 100, 1000]

params = [
    {"C": Cs, "kernel": ["linear"]},
    {"C": Cs, "degree": [2, 3, 4], "kernel": ["poly"]},
    {"C": Cs, "gamma": np.logspace(-9, 3, 13), "kernel": ["rbf"]},
]

cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
clf = HalvingGridSearchCV(estimator=SVC(),
                          param_grid=params,
                          cv=cv,
                          scoring="accuracy",
                          verbose=2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
clf.fit(X_train_trans, y_train)
# Out:
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 2480
# max_resources_: 66977
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 68
# n_resources: 2480
# Fitting 5 folds for each of 68 candidates, totalling 340 fits
# [CV] END .................................C=1, kernel=linear; total time=   1.8s
# [CV] END .................................C=1, kernel=linear; total time=   1.4s
# [CV] END .................................C=1, kernel=linear; total time=   0.7s
# [CV] END .................................C=1, kernel=linear; total time=   0.7s
# [CV] END .................................C=1, kernel=linear; total time=   0.8s
# [CV] END ................................C=10, kernel=linear; total time=   1.0s
# [CV] END ................................C=10, kernel=linear; total time=   0.7s
# [CV] END ................................C=10, kernel=linear; total time=   0.8s
# [CV] END ................................C=10, kernel=linear; total time=   0.7s
# [CV] END ................................C=10, kernel=linear; total time=   0.8s
# [CV] END ...............................C=100, kernel=linear; total time=  26.0s
# [CV] END ...............................C=100, kernel=linear; total time=  36.8s
# [CV] END ...............................C=100, kernel=linear; total time=   3.9s
# [CV] END ...............................C=100, kernel=linear; total time=  14.8s
# [CV] END ...............................C=100, kernel=linear; total time=   6.1s
# [CV] END ..............................C=1000, kernel=linear; total time= 5.6min
# [CV] END ..............................C=1000, kernel=linear; total time= 6.3min
# [CV] END ..............................C=1000, kernel=linear; total time= 1.3min
# [CV] END ..............................C=1000, kernel=linear; total time= 1.8min
# [CV] END ..............................C=1000, kernel=linear; total time=  40.2s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.4s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.3s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.4s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.4s
# [CV] END .........................C=1, degree=2, kernel=poly; total time=   0.4s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.4s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.6s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.6s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.6s
# [CV] END .........................C=1, degree=3, kernel=poly; total time=   0.6s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.7s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.5s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.4s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.5s
# [CV] END .........................C=1, degree=4, kernel=poly; total time=   0.4s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.5s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.5s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.5s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.5s
# [CV] END ........................C=10, degree=2, kernel=poly; total time=   0.5s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.6s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.5s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.6s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.6s
# [CV] END ........................C=10, degree=3, kernel=poly; total time=   0.5s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.8s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   1.3s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.9s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.8s
# [CV] END ........................C=10, degree=4, kernel=poly; total time=   0.7s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   1.7s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   1.9s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   1.5s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   1.9s
# [CV] END .......................C=100, degree=2, kernel=poly; total time=   1.7s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   4.8s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   1.9s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   2.2s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   3.0s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=   2.5s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   3.1s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   2.0s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   2.6s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   2.5s
# [CV] END .......................C=100, degree=4, kernel=poly; total time=   3.6s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=  16.8s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=  19.2s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=  23.9s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=  14.8s
# [CV] END ......................C=1000, degree=2, kernel=poly; total time=  14.0s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=  31.7s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=  18.9s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=  19.8s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=  16.6s
# [CV] END ......................C=1000, degree=3, kernel=poly; total time=  16.7s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=  21.4s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=  10.5s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=  19.3s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=  19.2s
# [CV] END ......................C=1000, degree=4, kernel=poly; total time=  12.0s
# [CV] END .......................C=1, gamma=1e-09, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=1e-09, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-08, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END .......................C=1, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END .......................C=1, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END .......................C=1, gamma=1e-07, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-07, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-06, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.6s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   0.6s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.6s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END .........................C=1, gamma=1.0, kernel=rbf; total time=   0.7s
# [CV] END .........................C=1, gamma=1.0, kernel=rbf; total time=   0.7s
# [CV] END .........................C=1, gamma=1.0, kernel=rbf; total time=   0.6s
# [CV] END .........................C=1, gamma=1.0, kernel=rbf; total time=   0.5s
# [CV] END .........................C=1, gamma=1.0, kernel=rbf; total time=   0.4s
# [CV] END ........................C=1, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END ........................C=1, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END ........................C=1, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END ........................C=1, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END ........................C=1, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END .......................C=1, gamma=100.0, kernel=rbf; total time=   0.6s
# [CV] END .......................C=1, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END .......................C=1, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END .......................C=1, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END .......................C=1, gamma=100.0, kernel=rbf; total time=   0.8s
# [CV] END ......................C=1, gamma=1000.0, kernel=rbf; total time=   0.9s
# [CV] END ......................C=1, gamma=1000.0, kernel=rbf; total time=   0.9s
# [CV] END ......................C=1, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END ......................C=1, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END ......................C=1, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END ......................C=10, gamma=1e-09, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-08, kernel=rbf; total time=   0.5s
# [CV] END ......................C=10, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-07, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END ......................C=10, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END ......................C=10, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END ......................C=10, gamma=1e-07, kernel=rbf; total time=   0.5s
# [CV] END ......................C=10, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   0.5s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   0.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.6s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.4s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   0.4s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   0.7s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   0.7s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   0.7s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   0.6s
# [CV] END .......................C=10, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END .......................C=10, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END .......................C=10, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END .......................C=10, gamma=10.0, kernel=rbf; total time=   0.5s
# [CV] END .......................C=10, gamma=10.0, kernel=rbf; total time=   0.6s
# [CV] END ......................C=10, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END ......................C=10, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END ......................C=10, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END ......................C=10, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END ......................C=10, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END .....................C=10, gamma=1000.0, kernel=rbf; total time=   0.9s
# [CV] END .....................C=10, gamma=1000.0, kernel=rbf; total time=   0.9s
# [CV] END .....................C=10, gamma=1000.0, kernel=rbf; total time=   0.9s
# [CV] END .....................C=10, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END .....................C=10, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END .....................C=100, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-09, kernel=rbf; total time=   0.3s
# [CV] END .....................C=100, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-08, kernel=rbf; total time=   0.3s
# [CV] END .....................C=100, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-07, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-07, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END .....................C=100, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END .....................C=100, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END .....................C=100, gamma=1e-06, kernel=rbf; total time=   0.5s
# [CV] END .....................C=100, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   0.6s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.6s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.7s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.6s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.4s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.5s
# [CV] END .......................C=100, gamma=1.0, kernel=rbf; total time=   0.7s
# [CV] END .......................C=100, gamma=1.0, kernel=rbf; total time=   0.9s
# [CV] END .......................C=100, gamma=1.0, kernel=rbf; total time=   1.0s
# [CV] END .......................C=100, gamma=1.0, kernel=rbf; total time=   0.8s
# [CV] END .......................C=100, gamma=1.0, kernel=rbf; total time=   0.5s
# [CV] END ......................C=100, gamma=10.0, kernel=rbf; total time=   0.7s
# [CV] END ......................C=100, gamma=10.0, kernel=rbf; total time=   0.7s
# [CV] END ......................C=100, gamma=10.0, kernel=rbf; total time=   0.6s
# [CV] END ......................C=100, gamma=10.0, kernel=rbf; total time=   0.6s
# [CV] END ......................C=100, gamma=10.0, kernel=rbf; total time=   0.6s
# [CV] END .....................C=100, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END .....................C=100, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END .....................C=100, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END .....................C=100, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END .....................C=100, gamma=100.0, kernel=rbf; total time=   1.0s
# [CV] END ....................C=100, gamma=1000.0, kernel=rbf; total time=   0.9s
# [CV] END ....................C=100, gamma=1000.0, kernel=rbf; total time=   0.7s
# [CV] END ....................C=100, gamma=1000.0, kernel=rbf; total time=   0.5s
# [CV] END ....................C=100, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END ....................C=100, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END ....................C=1000, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-09, kernel=rbf; total time=   0.3s
# [CV] END ....................C=1000, gamma=1e-09, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-08, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END ....................C=1000, gamma=1e-07, kernel=rbf; total time=   0.7s
# [CV] END ....................C=1000, gamma=1e-07, kernel=rbf; total time=   0.6s
# [CV] END ....................C=1000, gamma=1e-07, kernel=rbf; total time=   0.7s
# [CV] END ....................C=1000, gamma=1e-07, kernel=rbf; total time=   0.7s
# [CV] END ....................C=1000, gamma=1e-06, kernel=rbf; total time=   0.6s
# [CV] END ....................C=1000, gamma=1e-06, kernel=rbf; total time=   0.5s
# [CV] END ....................C=1000, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-06, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=1e-05, kernel=rbf; total time=   0.4s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   0.5s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   0.4s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   0.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   0.6s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   0.7s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   0.5s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   0.5s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   0.4s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   0.8s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   0.8s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   0.8s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   0.8s
# [CV] END .....................C=1000, gamma=0.01, kernel=rbf; total time=   0.8s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   1.4s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   2.0s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   1.9s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   1.1s
# [CV] END ......................C=1000, gamma=0.1, kernel=rbf; total time=   1.2s
# [CV] END ......................C=1000, gamma=1.0, kernel=rbf; total time=   1.4s
# [CV] END ......................C=1000, gamma=1.0, kernel=rbf; total time=   1.1s
# [CV] END ......................C=1000, gamma=1.0, kernel=rbf; total time=   1.2s
# [CV] END ......................C=1000, gamma=1.0, kernel=rbf; total time=   1.3s
# [CV] END ......................C=1000, gamma=1.0, kernel=rbf; total time=   1.3s
# [CV] END .....................C=1000, gamma=10.0, kernel=rbf; total time=   1.7s
# [CV] END .....................C=1000, gamma=10.0, kernel=rbf; total time=   1.2s
# [CV] END .....................C=1000, gamma=10.0, kernel=rbf; total time=   1.0s
# [CV] END .....................C=1000, gamma=10.0, kernel=rbf; total time=   1.1s
# [CV] END .....................C=1000, gamma=10.0, kernel=rbf; total time=   1.0s
# [CV] END ....................C=1000, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END ....................C=1000, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END ....................C=1000, gamma=100.0, kernel=rbf; total time=   0.7s
# [CV] END ....................C=1000, gamma=100.0, kernel=rbf; total time=   0.8s
# [CV] END ....................C=1000, gamma=100.0, kernel=rbf; total time=   1.0s
# [CV] END ...................C=1000, gamma=1000.0, kernel=rbf; total time=   1.0s
# [CV] END ...................C=1000, gamma=1000.0, kernel=rbf; total time=   0.9s
# [CV] END ...................C=1000, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END ...................C=1000, gamma=1000.0, kernel=rbf; total time=   0.6s
# [CV] END ...................C=1000, gamma=1000.0, kernel=rbf; total time=   0.6s
# ----------
# iter: 1
# n_candidates: 23
# n_resources: 7440
# Fitting 5 folds for each of 23 candidates, totalling 115 fits
# [CV] END .......................C=100, degree=3, kernel=poly; total time=  32.2s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=  37.7s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=  45.3s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=  55.3s
# [CV] END .......................C=100, degree=3, kernel=poly; total time=  51.1s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   4.8s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   5.2s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   5.2s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   4.7s
# [CV] END ........................C=10, gamma=1.0, kernel=rbf; total time=   6.1s
# [CV] END .................................C=1, kernel=linear; total time=   2.9s
# [CV] END .................................C=1, kernel=linear; total time=   3.1s
# [CV] END .................................C=1, kernel=linear; total time=   3.6s
# [CV] END .................................C=1, kernel=linear; total time=   3.3s
# [CV] END .................................C=1, kernel=linear; total time=   3.4s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   5.0s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   5.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   5.0s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   5.6s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   4.2s
# [CV] END ................................C=10, kernel=linear; total time=   6.0s
# [CV] END ................................C=10, kernel=linear; total time=   6.0s
# [CV] END ................................C=10, kernel=linear; total time=   5.0s
# [CV] END ................................C=10, kernel=linear; total time=   6.2s
# [CV] END ................................C=10, kernel=linear; total time=   5.3s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   4.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   4.1s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   5.2s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   3.9s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   5.1s
# [CV] END ...............................C=100, kernel=linear; total time= 7.7min
# [CV] END ...............................C=100, kernel=linear; total time= 7.5min
# [CV] END ...............................C=100, kernel=linear; total time=10.0min
# [CV] END ...............................C=100, kernel=linear; total time= 4.1min
# [CV] END ...............................C=100, kernel=linear; total time= 6.3min
# [CV] END ..............................C=1000, kernel=linear; total time=24.7min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-ce22136329cb> in <cell line: 1>()
# ----> 1 clf.fit(X_train_trans, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search_successive_halving.py in fit(self, X, y, groups, **fit_params)
#     271         self._n_samples_orig = _num_samples(X)
#     272
# --> 273         super().fit(X, y=y, groups=groups, **fit_params)
#     274
#     275         # Set best_score_: BaseSearchCV does not set it, as refit is a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search_successive_halving.py in _run_search(self, evaluate_candidates)
#     376             }
#     377
# --> 378             results = evaluate_candidates(
#     379                 candidate_params, cv, more_results=more_results
#     380             )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684             estimator.fit(X_train, **fit_params)
#     685         else:
# --> 686             estimator.fit(X_train, y_train, **fit_params)
#     687
#     688     except Exception:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     250
#     251         seed = rnd.randint(np.iinfo("i").max)
# --> 252         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     253         # see comment on the other call to np.iinfo in this file
#     254
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     329             self.fit_status_,
#     330             self._num_iter,
# --> 331         ) = libsvm.fit(
#     332             X,
#     333             y,
#
# KeyboardInterrupt:

# %%
model = clf.best_estimator_
model

# %%
from joblib import dump
dump(model, '/content/drive/My Drive/svm.joblib')

# %%
# from sklearn.metrics import confusion_matrix
#
# y_pred = model.predict(X_test)
#
# conf = confusion_matrix(y_test, y_pred)
#
# sns.heatmap(conf, cmap='GnBu', annot=True, fmt='g')
# plt.xlabel('Predicted')
# plt.ylabel('True')
